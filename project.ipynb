# %%
import pandas as pd
data = pd.read_csv('data.csv')
print(data.shape)
data.head()
# Out:
# (506, 14)
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         5
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
data.CHAS.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
data.RAD.unique()
# Out:
# array([ 1,  2,  3,  5,  4,  8,  6,  7, 24], dtype=int64)

# %%
data['RAD'].value_counts()
# Out:
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 2      24
# 8      24
# 1      20
# 7      17
# Name: RAD, dtype: int64

# %%
housing= data.loc[:,['RM','ZN','AGE','RAD','CRIM','NOX','TAX','INDUS','PTRATIO','LSTAT','MEDV']]

# %%
print(housing.shape)
housing.head()
# Out:
# (506, 11)
#       RM    ZN   AGE  RAD     CRIM    NOX  TAX  INDUS  PTRATIO  LSTAT  MEDV
# 0  6.575  18.0  65.2    1  0.00632  0.538  296   2.31     15.3   4.98  24.0
# 1  6.421   0.0  78.9    2  0.02731  0.469  242   7.07     17.8   9.14  21.6
# 2  7.185   0.0  61.1    2  0.02729  0.469  242   7.07     17.8   4.03  34.7
# 3  6.998   0.0  45.8    3  0.03237  0.458  222   2.18     18.7   2.94  33.4
# 4  7.147   0.0  54.2    3  0.06905  0.458  222   2.18     18.7   5.33  36.2

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'RM'}>,
#         <AxesSubplot:title={'center':'ZN'}>,
#         <AxesSubplot:title={'center':'AGE'}>],
#        [<AxesSubplot:title={'center':'RAD'}>,
#         <AxesSubplot:title={'center':'CRIM'}>,
#         <AxesSubplot:title={'center':'NOX'}>],
#        [<AxesSubplot:title={'center':'TAX'}>,
#         <AxesSubplot:title={'center':'INDUS'}>,
#         <AxesSubplot:title={'center':'PTRATIO'}>],
#        [<AxesSubplot:title={'center':'LSTAT'}>,
#         <AxesSubplot:title={'center':'MEDV'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# # Looking for Corretation

# %%
corr_matrix = data.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.696169
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %%
housing.plot(kind="scatter", x="RM", y="MEDV", alpha=.7)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="ZN", y="MEDV", alpha=.7)
# Out:
# <AxesSubplot:xlabel='ZN', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="AGE", y="MEDV", alpha=.7)
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="NOX", y="MEDV", alpha=.7)
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="CRIM", y="MEDV", alpha=.7)
# Out:
# <AxesSubplot:xlabel='CRIM', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="RAD", y="MEDV", alpha=.7)
# Out:
# <AxesSubplot:xlabel='RAD', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="TAX", y="MEDV", alpha=.7)
# Out:
# <AxesSubplot:xlabel='TAX', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="INDUS", y="MEDV", alpha=.7)
# Out:
# <AxesSubplot:xlabel='INDUS', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="PTRATIO", y="MEDV", alpha=.7)
# Out:
# <AxesSubplot:xlabel='PTRATIO', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="LSTAT", y="MEDV", alpha=.7)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>

# %% [markdown]
# # Train-Test Splitting

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)
print(f"row in train set : {len(train_set)}\nrow in test set : {len(test_set)}\n")
# Out:
# row in train set : 404
# row in test set : 102

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing['RAD']):
    start_train_set = housing.loc[train_index]
    start_test_set = housing.loc[test_index]

# %%
start_train_set
# Out:
#         RM    ZN   AGE  RAD      CRIM    NOX  TAX  INDUS  PTRATIO  LSTAT  MEDV
# 174  5.859   0.0  68.7    5   0.08447  0.510  296   4.05     16.6   9.64  22.6
# 121  6.004   0.0  84.1    2   0.07165  0.581  188  25.65     19.1  14.27  20.3
# 395  6.471   0.0  98.8   24   8.71675  0.693  666  18.10     20.2  17.12  13.1
# 444  5.854   0.0  96.6   24  12.80230  0.740  666  18.10     20.2  23.79  10.8
# 334  6.310   0.0  38.5    5   0.03738  0.515  224   5.19     20.2   6.75  20.7
# ..     ...   ...   ...  ...       ...    ...  ...    ...      ...    ...   ...
# 416  6.782   0.0  90.8   24  10.83420  0.679  666  18.10     20.2  25.79   7.5
# 250  6.487  22.0  13.0    7   0.14030  0.431  330   5.86     19.1   5.90  24.4
# 34   6.096   0.0  96.9    4   1.61282  0.538  307   8.14     21.0  20.34  13.5
# 11   6.009  12.5  82.9    5   0.11747  0.524  311   7.87     15.2  13.27  18.9
# 123  5.856   0.0  97.0    2   0.15038  0.581  188  25.65     19.1  25.41  17.3
#
# [404 rows x 11 columns]

# %%
start_train_set['RAD'].value_counts()
# Out:
# 24    105
# 5      92
# 4      88
# 3      30
# 6      21
# 2      19
# 8      19
# 1      16
# 7      14
# Name: RAD, dtype: int64

# %%
start_test_set['RAD'].value_counts()
# Out:
# 24    27
# 5     23
# 4     22
# 3      8
# 2      5
# 6      5
# 8      5
# 1      4
# 7      3
# Name: RAD, dtype: int64

# %%
#105/27

# %%
#92/23

# %%
#14/3

# %%
housing=start_train_set.copy()

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 174 to 123
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       399 non-null    float64
#  1   ZN       404 non-null    float64
#  2   AGE      404 non-null    float64
#  3   RAD      404 non-null    int64
#  4   CRIM     404 non-null    float64
#  5   NOX      404 non-null    float64
#  6   TAX      404 non-null    int64
#  7   INDUS    404 non-null    float64
#  8   PTRATIO  404 non-null    float64
#  9   LSTAT    404 non-null    float64
#  10  MEDV     404 non-null    float64
# dtypes: float64(9), int64(2)
# memory usage: 37.9 KB

# %%
from pandas.plotting import scatter_matrix
attributes = ["MEDV", "RM", "ZN", "LSTAT"]
scatter_matrix(housing[attributes], figsize=(12,8))
# Out:
# array([[<AxesSubplot:xlabel='MEDV', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='RM', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='ZN', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='RM'>,
#         <AxesSubplot:xlabel='RM', ylabel='RM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='RM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RM'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='ZN'>,
#         <AxesSubplot:xlabel='RM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='ZN'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='ZN', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind="scatter", x="RM", y="MEDV", alpha=.7)  # for single
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
housing = start_train_set.drop("MEDV", axis=1)
housing_labels = start_train_set["MEDV"].copy()

# %% [markdown]
# # Missing Attributes

# %%
median= data["RM"].median()  
#housing["RM"].fillna(median)
median
# Out:
# 6.208

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_   #show all column median
# Out:
# array([6.2110e+00, 0.0000e+00, 7.7700e+01, 5.0000e+00, 2.2948e-01,
#        5.3800e-01, 3.3200e+02, 9.6900e+00, 1.9100e+01, 1.1430e+01])

# %%
X = imputer.transform(housing)
housing_tr = pd.DataFrame(X, columns=housing.columns)
housing_tr.describe()
# Out:
#                RM          ZN         AGE         RAD        CRIM         NOX  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     6.280562   11.300743   68.298020    9.534653    3.373498    0.555415
# std      0.716406   23.178357   28.357544    8.696783    7.517897    0.117047
# min      3.561000    0.000000    2.900000    1.000000    0.006320    0.385000
# 25%      5.888000    0.000000   45.075000    4.000000    0.081960    0.448750
# 50%      6.211000    0.000000   77.700000    5.000000    0.229480    0.538000
# 75%      6.604500   12.500000   93.425000   24.000000    3.678530    0.624000
# max      8.780000  100.000000  100.000000   24.000000   73.534100    0.871000
#
#               TAX       INDUS     PTRATIO       LSTAT
# count  404.000000  404.000000  404.000000  404.000000
# mean   409.915842   11.210792   18.492079   12.733465
# std    168.821540    6.952594    2.150904    7.229658
# ...

# %% [markdown]
# # Create Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
my_pipeline = Pipeline([
    ('impute', SimpleImputer(strategy="median")),
       #...... add so many as you want in your pipeline
    #('std_scaler', StandardScaler() ),#feature scaling
])

# %%
housing_num_tr = my_pipeline.fit_transform(housing)
housing_num_tr
# Out:
# array([[ 5.859,  0.   , 68.7  , ...,  4.05 , 16.6  ,  9.64 ],
#        [ 6.004,  0.   , 84.1  , ..., 25.65 , 19.1  , 14.27 ],
#        [ 6.471,  0.   , 98.8  , ..., 18.1  , 20.2  , 17.12 ],
#        ...,
#        [ 6.096,  0.   , 96.9  , ...,  8.14 , 21.   , 20.34 ],
#        [ 6.009, 12.5  , 82.9  , ...,  7.87 , 15.2  , 13.27 ],
#        [ 5.856,  0.   , 97.   , ..., 25.65 , 19.1  , 25.41 ]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor # overfitting
from sklearn.ensemble import RandomForestRegressor
#model = LinearRegression()
#model =  DecisionTreeRegressor()
model = RandomForestRegressor(n_estimators=60,max_depth=5)
model.fit(housing_num_tr, housing_labels)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=60)

# %%
x = start_test_set.drop("MEDV", axis=1)
y = start_test_set["MEDV"].copy()

# %%
some_data = housing.iloc[:10]
some_labels = housing_labels.iloc[:10]
prepare_data = my_pipeline.transform(some_data)
prepare_data
# Out:
# array([[5.85900e+00, 0.00000e+00, 6.87000e+01, 5.00000e+00, 8.44700e-02,
#         5.10000e-01, 2.96000e+02, 4.05000e+00, 1.66000e+01, 9.64000e+00],
#        [6.00400e+00, 0.00000e+00, 8.41000e+01, 2.00000e+00, 7.16500e-02,
#         5.81000e-01, 1.88000e+02, 2.56500e+01, 1.91000e+01, 1.42700e+01],
#        [6.47100e+00, 0.00000e+00, 9.88000e+01, 2.40000e+01, 8.71675e+00,
#         6.93000e-01, 6.66000e+02, 1.81000e+01, 2.02000e+01, 1.71200e+01],
#        [5.85400e+00, 0.00000e+00, 9.66000e+01, 2.40000e+01, 1.28023e+01,
#         7.40000e-01, 6.66000e+02, 1.81000e+01, 2.02000e+01, 2.37900e+01],
#        [6.31000e+00, 0.00000e+00, 3.85000e+01, 5.00000e+00, 3.73800e-02,
#         5.15000e-01, 2.24000e+02, 5.19000e+00, 2.02000e+01, 6.75000e+00],
#        [6.29000e+00, 8.00000e+01, 1.78000e+01, 4.00000e+00, 3.58400e-02,
#         3.98000e-01, 3.37000e+02, 3.37000e+00, 1.61000e+01, 4.67000e+00],
#        [3.86300e+00, 0.00000e+00, 1.00000e+02, 2.40000e+01, 1.35222e+01,
# ...

# %%
model.predict(prepare_data)
# Out:
# array([22.16552915, 21.24298509, 14.34817043,  9.78424064, 23.7070787 ,
#        24.35485404, 20.13417029, 25.09658498, 19.85618485, 20.43416062])

# %%
list(some_labels)
# Out:
# [22.6, 20.3, 13.1, 10.8, 20.7, 23.5, 23.1, 27.5, 23.1, 21.7]

# %% [markdown]
# # Evaluation the Model

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
housing_predictions = model.predict(housing_num_tr)
mse = mean_squared_error(housing_labels, housing_predictions)
rmse = np.sqrt(mse)
print("rmse : ",rmse)
# Out:
# rmse :  2.3334363608634985

# %%
from sklearn.metrics import mean_absolute_error, r2_score
print("MEA :",mean_absolute_error(housing_labels, housing_predictions))
r2_score(housing_labels, housing_predictions)
# Out:
# MEA : 1.733877574519336
# 0.9331855231986198

# %% [markdown]
# # Save The Model

# %%
from joblib import dump, load
dump(model, 'house_price_predict_model.joblib')
# Out:
# ['house_price_predict_model.joblib']

# %% [markdown]
# # Testing The Model on test Data Set

# %%
X_test = start_test_set.drop("MEDV", axis=1)
Y_test = start_test_set["MEDV"].copy()
X_test_prepared = my_pipeline.transform(X_test)
final_predictions = model.predict(X_test_prepared)
final_mse = mean_squared_error(Y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
print(final_predictions, list(Y_test))
# Out:
# [20.24379074 22.61693816 17.01553416 23.13738955 27.89363354 25.20167456
#  12.04067978 23.22088778 14.24089551 14.58636061 14.26998501 20.13885169
#  17.30735811 20.69558628 26.28308879 47.24056135 49.4687026  14.96363999
#  20.19974057 22.57812134 15.31467246 23.83666058 29.32093964  9.16249057
#  19.26082924 30.28240364 15.90861266 26.99248363 15.394619   20.34218179
#  23.03728287 24.72582704 22.64853061 14.14481841 22.82335642 27.10036627
#  23.68388921 20.32830955 41.74529755 34.52198168 12.56209702 30.93762235
#  22.47718124 22.63881367 16.52486179 22.81409601 25.90235833 22.89921476
#  22.56082107 20.56545438 23.30361401 28.65047163 34.14982601 33.22299305
#  30.04351788 12.85331026 19.08223754 19.00911963 24.80991396 20.07651701
#  29.4172894  23.77534364 23.78215011 20.33405979 23.83857811 20.28388077
#  12.79993952 32.53162404 18.52076741 18.09104446 37.84826207 22.42149161
#  14.94156705 16.55161147 19.93222247 35.16689079 27.40588315 18.82416911
# ...

# %% [markdown]
# # Export Model

# %%
#import sklearn.external.joblib as extjoblib
import joblib
#from sklearn.externals import joblib
joblib.dump(model,'house_price_predict_model.ml')
# Out:
# ['house_price_predict_model.ml']
